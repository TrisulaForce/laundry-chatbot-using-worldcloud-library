# %%
# Kamus untuk kata kunci dan responsnya
responses = {
    "Cara_pembuatan_chemical": {
        "keywords": ["chemical", "pembuatan chemical", "cara membuat chemical"],
        "response": "Untuk membuat chemical, Anda perlu mengikuti langkah-langkah berikut: ..."
    },
    "Manajemen_Pelayanan": {
        "keywords": ["manajemen pelayanan", "pelayanan", "manajemen"],
        "response": "Manajemen pelayanan merupakan hal yang penting dalam bisnis laundry. Anda perlu memastikan ..."
    },
    "Labelling_Pakaian": {
        "keywords": ["labelling pakaian", "label pakaian", "penanda pakaian"],
        "response": "Labelling pakaian adalah cara yang efektif untuk menghindari kesalahan penanganan pakaian. Anda bisa menggunakan ..."
    },
    "Teknik_Laundry_Kiloan_Satuan": {
        "keywords": ["teknik laundry kiloan", "teknik laundry satuan", "laundry kiloan", "laundry satuan"],
        "response": "Ada berbagai teknik untuk laundry kiloan dan satuan. Untuk laundry kiloan, Anda bisa ..."
    },
    "Cara_menghilangkan_noda": {
        "keywords": ["menghilangkan noda", "noda pada pakaian", "cara menghilangkan noda"],
        "response": "Menghilangkan noda pada pakaian bisa dilakukan dengan berbagai cara, tergantung ..."
    },
    "Metode_Packing_Laundry_Kiloan": {
        "keywords": ["packing laundry kiloan", "packing kiloan", "packing pakaian"],
        "response": "Packing laundry kiloan harus dilakukan dengan hati-hati untuk menjaga agar pakaian tetap rapi dan terjaga kualitasnya. ..."
    },
    "Metode_Packing_Laundry_Bijian": {
        "keywords": ["packing laundry bijian", "packing bijian", "packing pakaian bijian"],
        "response": "Packing laundry bijian bisa dilakukan dengan menggunakan hanger untuk pakaian yang memerlukan, dan untuk pakaian lainnya ..."
    },
    "Manajemen_Komplain_Kepegawaian": {
        "keywords": ["komplain pelanggan", "manajemen komplain", "manajemen kepegawaian"],
        "response": "Manajemen komplain pelanggan dan kepegawaian merupakan bagian penting dari bisnis laundry. ..."
    }
}

# Fungsi untuk mengembalikan respons berdasarkan input pengguna
def get_response(user_input):
    for key in responses:
        if any(keyword in user_input.lower() for keyword in responses[key]["keywords"]):
            return responses[key]["response"]
    return "Maaf, saya tidak bisa membantu dengan pertanyaan tersebut."

# Contoh penggunaan chatbot
while True:
    user_input = input("Masukkan pertanyaan Anda: ")
    if user_input.lower() == "exit":
        break
    response = get_response(user_input)
    print(response)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-d608618b87e1> in <cell line: 45>()
#      44 # Contoh penggunaan chatbot
#      45 while True:
# ---> 46     user_input = input("Masukkan pertanyaan Anda: ")
#      47     if user_input.lower() == "exit":
#      48         break
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
# ...

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Download stopwords jika belum ada
nltk.download('punkt')
nltk.download('stopwords')

# Daftar kata kunci dan jawaban
keywords = {
    'CARA PEMBUATAN CHEMICAL': """
    Ini adalah jawaban untuk topik Cara Pembuatan Chemical.
    """,
    'MANAJEMEN PELAYANAN': """
    Ini adalah jawaban untuk topik Manajemen Pelayanan.
    """,
    'LABELLING PAKAIAN': """
    Ini adalah jawaban untuk topik Labelling Pakaian.
    """,
    'TEKNIK LAUNDRY KILOAN & SATUAN': """
    Ini adalah jawaban untuk topik Teknik Laundry Kiloan & Satuan.
    """,
    'CARA MENGHILANGKAN NODA': """
    Ini adalah jawaban untuk topik Cara Menghilangkan Noda.
    """,
    'METODE PACKING LAUNDRY KILOAN & SATUAN': """
    Ini adalah jawaban untuk topik Metode Packing Laundry Kiloan & Satuan.
    """,
    'MANAJEMEN KOMPLAIN & KEPEGAWAIAN': """
    Ini adalah jawaban untuk topik Manajemen Komplain & Kepegawaian.
    """
}

# Fungsi untuk membuat WordCloud dari teks
def create_wordcloud(text):
    tokens = word_tokenize(text)
    stop_words = set(stopwords.words('indonesian')) # Menggunakan stopword bahasa Indonesia
    tokens = [word.lower() for word in tokens if word.isalpha() and word.lower() not in stop_words]
    cleaned_text = ' '.join(tokens)
    wordcloud = WordCloud(width=800, height=400, background_color='white').generate(cleaned_text)
    plt.figure(figsize=(10, 8))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.show()

# Fungsi utama chatbot
def chatbot():
    print("Selamat datang di Chatbot WordCloud!")
    print("Silakan pilih topik berikut:")
    print("1. Cara Pembuatan Chemical")
    print("2. Manajemen Pelayanan")
    print("3. Labelling Pakaian")
    print("4. Teknik Laundry Kiloan & Satuan")
    print("5. Cara Menghilangkan Noda")
    print("6. Metode Packing Laundry Kiloan & Satuan")
    print("7. Manajemen Komplain & Kepegawaian")
    print("Ketik 'selesai' untuk keluar.")

    while True:
        topic = input("Masukkan nomor topik: ")
        if topic == 'selesai':
            print("Terima kasih telah menggunakan Chatbot WordCloud!")
            break
        elif topic.isdigit() and 1 <= int(topic) <= 7:
            topic = int(topic)
            topic_mapping = {
                1: 'CARA PEMBUATAN CHEMICAL',
                2: 'MANAJEMEN PELAYANAN',
                3: 'LABELLING PAKAIAN',
                4: 'TEKNIK LAUNDRY KILOAN & SATUAN',
                5: 'CARA MENGHILANGKAN NODA',
                6: 'METODE PACKING LAUNDRY KILOAN & SATUAN',
                7: 'MANAJEMEN KOMPLAIN & KEPEGAWAIAN'
            }
            selected_topic = topic_mapping[topic]
            print("Anda memilih topik:", selected_topic)
            print("Silakan bertanya atau ketik 'selesai' untuk kembali ke menu.")
            while True:
                question = input("Pertanyaan Anda: ")
                if question == 'selesai':
                    break
                else:
                    if selected_topic in keywords:
                        print(keywords[selected_topic])
                        create_wordcloud(keywords[selected_topic])
                    else:
                        print("Topik tidak valid. Silakan pilih topik lain.")
        else:
            print("Input tidak valid. Silakan pilih nomor topik yang sesuai.")

# Jalankan chatbot
chatbot()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Selamat datang di Chatbot WordCloud!
# Silakan pilih topik berikut:
# 1. Cara Pembuatan Chemical
# 2. Manajemen Pelayanan
# 3. Labelling Pakaian
# 4. Teknik Laundry Kiloan & Satuan
# 5. Cara Menghilangkan Noda
# 6. Metode Packing Laundry Kiloan & Satuan
# 7. Manajemen Komplain & Kepegawaian
# Ketik 'selesai' untuk keluar.
# Masukkan nomor topik: 1
# Anda memilih topik: CARA PEMBUATAN CHEMICAL
# Silakan bertanya atau ketik 'selesai' untuk kembali ke menu.
# Pertanyaan Anda: cara pembuatan chemical
#
#     Ini adalah jawaban untuk topik Cara Pembuatan Chemical.

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Download stopwords jika belum ada
nltk.download('stopwords')

# Daftar kata kunci dan jawaban
keywords = {
    'LABELLING PAKAIAN': """
    Agar pakaian pelanggan tidak tertukar, Anda bisa menggunakan metode labelling.
    Beberapa perlengkapan yang diperlukan adalah pistol label (Tag gun), tali label (Tag pin), kain label, dan spidol Permanent Marker.
    Pistol label biasanya dapat dibeli di toko-toko yang menjual peralatan konveksi atau di toko alat tulis dengan harga sekitar Rp. 25 ribu.
    """,
    'CARA MENGHILANGKAN NODA': """
    Untuk menghilangkan noda pada pakaian, Anda bisa mencoba beberapa metode seperti penggunaan alkohol untuk noda tinta, Bayclin pemutih untuk baju putih, dan cairan thinner untuk noda tinta printer.
    """,
    'METODE PACKING LAUNDRY KILOAN': """
    Urutan yang benar untuk packing kiloan adalah: celana tebal, celana biasa, celana pendek, handuk, sprei, kaos dalam, celana dalam, kaos tanpa kerah, kaos berkerah, dan kemeja berkerah.
    Perlengkapan yang perlu disiapkan untuk metode labelling adalah pistol label (Tag gun), tali label (Tag pin), kain label, dan spidol Permanent Marker.
    """
}

# Fungsi untuk membuat WordCloud dari teks
def create_wordcloud(text):
    tokens = word_tokenize(text)
    stop_words = set(stopwords.words('english'))
    tokens = [word.lower() for word in tokens if word.isalpha() and word.lower() not in stop_words]
    cleaned_text = ' '.join(tokens)
    wordcloud = WordCloud(width=800, height=400, background_color='white').generate(cleaned_text)
    plt.figure(figsize=(10, 8))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.show()

# Fungsi utama chatbot
def chatbot():
    print("Selamat datang di Chatbot WordCloud!")
    print("Silakan pilih topik berikut: LABELLING PAKAIAN, CARA MENGHILANGKAN NODA, METODE PACKING LAUNDRY KILOAN")
    print("Ketik 'selesai' untuk keluar.")

    while True:
        topic = input("Masukkan topik: ").upper()

        if topic == 'SELESAI':
            print("Terima kasih telah menggunakan Chatbot WordCloud!")
            break

        if topic in keywords:
            print(keywords[topic])
            create_wordcloud(keywords[topic])
        else:
            print("Maaf, topik yang Anda masukkan tidak valid. Silakan coba lagi.")

# Jalankan chatbot
chatbot()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Selamat datang di Chatbot WordCloud!
# Silakan pilih topik berikut: LABELLING PAKAIAN, CARA MENGHILANGKAN NODA, METODE PACKING LAUNDRY KILOAN
# Ketik 'selesai' untuk keluar.
# Masukkan topik: LABELLING PAKAIAN
#
#     Agar pakaian pelanggan tidak tertukar, Anda bisa menggunakan metode labelling.
#     Beberapa perlengkapan yang diperlukan adalah pistol label (Tag gun), tali label (Tag pin), kain label, dan spidol Permanent Marker.
#     Pistol label biasanya dapat dibeli di toko-toko yang menjual peralatan konveksi atau di toko alat tulis dengan harga sekitar Rp. 25 ribu.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-272025755e1c> in <cell line: 58>()
#      56
#      57 # Jalankan chatbot
# ---> 58 chatbot()
#
# ...

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Download stopwords jika belum ada
nltk.download('stopwords')

# Daftar kata kunci dan jawaban
keywords = {
    'LABELLING PAKAIAN': {
        'Agar pakaian pelanggan tidak tertukar': """
            Ada beberapa cara yang dapat anda lakukan untuk mengatasi permasalah di atas:
            Metode menjemur berbeda arah.
            Metode satu pelanggan satu mesin cuci.
            Metode mengingat-mengingat.
            Metode labelling.
            Nah, di antara beberapa metode tersebut, metode yang paling tidak beresiko adalah
            Metode labelling.
            """,
        'Perlengkapan yang dibutuhkan untuk metode labelling': """
            Berikut ini perlengkapan yang perlu anda siapkan untuk metode labelling:
            1. Pistol label (Tag gun)
            2. Tali label (Tag pin)
            3. Kain label
            4. Spidol Permanent Marker (Bukan spidol yang Board Marker untuk menulis di papan tulis)
            """,
        'Di mana membeli pistol label': """
            Pistol label biasanya dapat dibeli di toko-toko yang menjual peralatan konveksi atau di toko alat tulis.
            """,
        'Harga pistol label': """
            Harganya berkisar antara Rp. 25 ribu.
            """,
        'Apa yang harus dilakukan jika jarum pistol label semakin menumpul atau patah': """
            Jika jarum pistol label semakin menumpul atau patah, kita bisa menggantinya dengan yang baru.
            """,
        'Di mana membeli pistol label tanpa perlu membeli satu paket komplit': """
            Pistol label biasanya dapat dibeli di toko-toko yang menjual peralatan konveksi atau di toko alat tulis. Harga jarum sekitar Rp. 3 ribu rupiah.
            """,
        'Ukuran standar untuk tag pin (tali label) dalam keperluan labelling laundry': """
            Ukuran standar untuk tag pin adalah 25 mm.
            """,
        'Apa yang bisa digunakan sebagai kain label': """
            Anda bisa menggunakan kain keras atau pita label sebagai kain label.
            """,
        'Mengapa penting menggunakan spidol permanent marker untuk menulis pada kain keras': """
            Spidol permanent marker digunakan karena tahan air dan tidak akan terhapus saat pakaian melalui proses pencucian.
            """
    },
    # Tambahkan topik lain di sini...
}

# Fungsi untuk membuat WordCloud dari teks
def create_wordcloud(text):
    tokens = word_tokenize(text)
    stop_words = set(stopwords.words('english'))
    tokens = [word.lower() for word in tokens if word.isalpha() and word.lower() not in stop_words]
    cleaned_text = ' '.join(tokens)
    wordcloud = WordCloud(width=800, height=400, background_color='white').generate(cleaned_text)
    plt.figure(figsize=(10, 8))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.show()

# Fungsi utama chatbot
def chatbot():
    print("Selamat datang di Chatbot WordCloud!")
    print("Silakan ajukan pertanyaan Anda atau ketik 'selesai' untuk keluar.")

    while True:
        question = input("Pertanyaan Anda: ").lower()

        if question == 'selesai':
            print("Terima kasih telah menggunakan Chatbot WordCloud!")
            break

        found_answer = False
        for topic in keywords:
            for key in keywords[topic]:
                if key.lower() in question:
                    print(keywords[topic][key])
                    create_wordcloud(keywords[topic][key])
                    found_answer = True
                    break
            if found_answer:
                break

        if not found_answer:
            print("Maaf, pertanyaan Anda tidak dapat dijawab. Apakah ada pertanyaan lain yang ingin Anda ajukan?")

# Jalankan chatbot
chatbot()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# Selamat datang di Chatbot WordCloud!
# Silakan ajukan pertanyaan Anda atau ketik 'selesai' untuk keluar.
